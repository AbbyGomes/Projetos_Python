# %% [markdown]
# <a href="https://colab.research.google.com/github/AbbyGomes/Projetos_Python/blob/main/An%C3%A1lise_explorat%C3%B3ria_CIAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BIGA-DATA - ANÁLISE EXPLORATÓRIA DOS DADOS USANDO DATASET SUSEP

# %% [markdown]
# Importando as bibliotecas panda, numphy, seaborn

# %%
 #import pandas as pd #1a celula

dados_susep = pd.read_excel("/content/biga_temp.xlsx")#, skiprows=0,  skipfooter=0, thousands='.', decimal=',') #2ª célula
dados_susep.head()
# Out:
#    Período  Coenti        Cias  Grupo Segurador   Ramos Agrupamento Ramos  \
# 0   202101    1007  SABEMI SEG.      SABEMI SEG.    929          Pessoas
# 1   202102    1007  SABEMI SEG.      SABEMI SEG.    929          Pessoas
# 2   202103    1007  SABEMI SEG.      SABEMI SEG.    929          Pessoas
# 3   202104    1007  SABEMI SEG.      SABEMI SEG.    929          Pessoas
# 4   202105    1007  SABEMI SEG.      SABEMI SEG.    929          Pessoas
#
#    Prêmio Emitido Liquido  Prêmio Retido  Prêmio Ganho  Sinistro Retido  \
# 0                 1140.40         399.03        399.03          2453.51
# 1                 1129.89         395.27        395.27         12830.03
# 2                23133.08       22398.46      22398.46        -35110.68
# 3                23398.14       22664.55      22664.55          9785.16
# 4                43033.30       42224.03      42224.03          1059.91
#
#      %  S/PG  Desp. Comercialização    % S/PG  Contribuição Marginal
# ...

# %%
#--como importar xlsx no pandas
#aula1 fase 1.2
#pode usar googoldocs mas não precisa no python
#import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt # formatação dos grafifcos
import warnings

#import streamlit as st
#Avisos
warnings.filterwarnings('ignore')


# @title Texto de título padrão

# %%
dados_susep.dtypes #para saber se importou e quais as colunas serão tratadas
# Out:
# Período                     int64
# Coenti                      int64
# Cias                       object
# Grupo Segurador            object
# Ramos                       int64
# Agrupamento Ramos          object
# Prêmio Emitido Liquido    float64
# Prêmio Retido             float64
# Prêmio Ganho              float64
# Sinistro Retido           float64
# %  S/PG                   float64
# Desp. Comercialização     float64
# % S/PG                    float64
# Contribuição Marginal     float64
# dtype: object

# %% [markdown]
# 1o passo: Formatar cabeçalho da tabela DADOS_SUSEP

# %%
print(f'Tamanho do nosso dataset: {dados_susep.shape}') #linhas e colunas
# Out:
# Tamanho do nosso dataset: (27, 14)

# %%
print(f'Quantidade dados nulos: {dados_susep.isnull().sum().sum()}')#verifica valores nulos
# Out:
# Quantidade dados nulos: 0

# %%
dados_susep.columns = ['Periodo','Coenti','Cia_Seguradora','Grupo_Segurador','Ramo','Agrupamento_Ramo','Pr_Emi_liq','Pr_Retido','Pr_Ganho','Sin_retido','perc_spg_sinretido','desp_comerc','perc_spg_desp','Cont_Margin']

# %%
df_ciaseg2 = dados_susep[['Periodo','Grupo_Segurador','perc_spg_sinretido']]

# %%
#df_tst = df_ciaseg.head() para trabalhar com algumas linhas somente

# %%
df_ciaseg = df_ciaseg.set_index("Periodo") #data frame tem índice

# %%
df_ciaseg2
# Out:
#                Grupo_Segurador  perc_spg_sinretido
# Periodo
# 202101             SABEMI SEG.            6.148686
# 202102             SABEMI SEG.           32.458902
# 202103             SABEMI SEG.           -1.567549
# 202104             SABEMI SEG.            0.431739
# 202105             SABEMI SEG.            0.025102
# 202106             SABEMI SEG.            0.214732
# 202107             SABEMI SEG.            0.106989
# 202108             SABEMI SEG.            0.087714
# 202109             SABEMI SEG.            0.083033
# 202110             SABEMI SEG.            0.180035
# 202111             SABEMI SEG.            0.073365
# 202112             SABEMI SEG.            0.051595
# 202201             SABEMI SEG.           -0.010121
# 202202             SABEMI SEG.            0.380282
# 202203             SABEMI SEG.            0.630284
# 202204             SABEMI SEG.            0.256499
# 202205             SABEMI SEG.            0.128587
# ...

# %%
df_ciaseg2= df_ciaseg.groupby('Periodo').sum()

# %%
dff=df_ciaseg2.T

# %%
# Out:
#                Grupo_Segurador perc_spg_sinretido
# Periodo
# 202101             SABEMI SEG.           6.148686
# 202102             SABEMI SEG.          32.458902
# 202103             SABEMI SEG.          -1.567549
# 202104             SABEMI SEG.           0.431739
# 202105             SABEMI SEG.           0.025102
# 202106             SABEMI SEG.           0.214732
# 202107             SABEMI SEG.           0.106989
# 202108             SABEMI SEG.           0.087714
# 202109             SABEMI SEG.           0.083033
# 202110             SABEMI SEG.           0.180035
# 202111             SABEMI SEG.           0.073365
# 202112             SABEMI SEG.           0.051595
# 202201             SABEMI SEG.          -0.010121
# 202202             SABEMI SEG.           0.380282
# 202203             SABEMI SEG.           0.630284
# 202204             SABEMI SEG.           0.256499
# 202205             SABEMI SEG.           0.128587
# 202206             SABEMI SEG.           0.021672
# ...

# %%
#dff = dff.drop("Grupo_Segurador")
dffseg = dffseg.drop("Periodo")

#.plot(figsize=(12,6))
#  depois de gerar a tabela com informação e valor

#dffseg=dffseg.T

# %%
#df_ciaseg.loc["202301"]
#df_periodo = df_periodo.set_index("Periodo")
df_ciaseg
df_periodo

# %%
#dft_periodo = df_periodo.T
#no lugar de transpor com .T, vou usar 3 colunas, e jogar o valor em 1
data = {'Periodo': ['Q', 'Q2'],
'Allianz' : [100,120],
'Bradesco': [12,80]}

# %%
df_long
# Out:
#   Periodo Grupo_segurador  perc_segur
# 0       Q         Allianz         100
# 1      Q2         Allianz         120
# 2       Q        Bradesco          12
# 3      Q2        Bradesco          80

# %%
#df_longi.iloc[("Periodo").-1] #não funciona

# %%
df_ciaseg

# %%
#não df_long.loc("Q")#.loc[3])
#df_longi["Q"]
#df_longi.loc["A"] #FUNCIONA
#incluir buscar o último período pelo loc em uma variável
#df_ciaseg.max()
#df_ciaseg.loc[202301] #usar a variável
# Out:
# Grupo_Segurador       SABEMI SEG.
# perc_spg_sinretido      32.458902
# dtype: object

# %%
df_long.plot(figsize=(6,3))
# Out:
# <Axes: >

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('Grupo_Segurador').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#df_ciaseg.head()
#df_longi.head() #indice é o periodo
#df_longi.loc["Q"]
#df_ciaseg.loc[dados_susep["Periodo"].iloc[-1]]
df_ciaseg.loc[dados_susep["Periodo"].iloc[-1]] #campo é numérico
# Out:
#         Grupo_Segurador  perc_spg_sinretido
# Periodo
# 202301      SABEMI SEG.            0.324543
# 202301       Allianzseg            0.324543

# %%
 df_longi = df_long.set_index("Periodo")

# %% [markdown]
# Busca todas as informações referentes ao último periodo

# %%
 #--biga
#df_longi.loc[df_longi.columns.iloc[-1]]
#BUSCA último periodo
#df_longi["Grupo_segurador"].iloc[-1] #traz o ultimo segu
#df_longi.loc["Q"]#("Grupo_Segurador")#.iloc[-1]
#df_longi.loc[df_long["Periodo"].iloc[-1]]
df_longi.iloc[-1]
# Out:
# Grupo_segurador    Bradesco
# perc_segur               80
# Name: Q2, dtype: object

# %%
df_periodo = dados_susep[['Periodo''perc_spg_sinretido']]
df_periodo["Periodo"] = df_periodo["Periodo"].astype(object)
#df_periodo = df_periodo.set_index("Periodo")

# %%
df_periodo.mean(numeric_only=True)
# Out:
# perc_spg_sinretido    1.57667
# dtype: float64

# %%
dft_periodo=df_periodo.T

# %%
dft_periodo.mean(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
df_usaveis = dft_periodo.index.Tolist #(0,"Grupo_Segurador")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-42be3f5ac7cd> in <cell line: 1>()
# ----> 1 df_usaveis = dft_periodo.index.Tolist #(0,"Grupo_Segurador")
#
# NameError: name 'dft_periodo' is not defined

# %%
df_periodotr
# Out:
# Periodo               202101     202102    202103    202104    202105  \
# perc_spg_sinretido  6.148686  32.458902 -1.567549  0.431739  0.025102
#
# Periodo               202106    202107    202108    202109    202110  ...  \
# perc_spg_sinretido  0.214732  0.106989  0.087714  0.083033  0.180035  ...
#
# Periodo               202205    202206    202207    202208    202209  \
# perc_spg_sinretido  0.128587  0.021672  0.112928  0.445678 -0.070123
#
# Periodo               202210    202211    202212    202301    202301
# perc_spg_sinretido  0.024049  0.157416 -0.027171  0.324543  0.324543
#
# [1 rows x 26 columns]
# ...

# %%
#df = df_periodo(df_periodo, ignore_index=True)
ultimo_mes    = df_ciaseg["Periodo"].iloc[-1]
ult_cia=df_ciaseg["Grupo_Segurador"].iloc[-1]
df_cias2 = df_ciaseg.loc[3]

print(ultimo_mes)
print(ult_cia)
print(df_cias2)
#
# Out:
# 202301
# Allianzseg
# Periodo                    202104
# Grupo_Segurador       SABEMI SEG.
# perc_spg_sinretido       0.431739
# Name: 3, dtype: object

# %%
 dados = df_ciaseg.set_index("Periodo")

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 202101 to 202301
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Grupo_Segurador     26 non-null     object
#  1   perc_spg_sinretido  26 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 624.0+ bytes

# %%
dados.iloc[-1]
# Out:
# Grupo_Segurador       Allianzseg
# perc_spg_sinretido      0.324543
# Name: 202301, dtype: object

# %%
dados.name()

# %%
 df_periodo2 = dados_susep['Periodo'=ultimo]

# %%
ultimo.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c21107feed4c> in <cell line: 1>()
# ----> 1 ultimo.head()
#
# AttributeError: 'numpy.int64' object has no attribute 'head'

# %%
df_periodo.head()
# Out:
#    Periodo  perc_spg_sinretido
# 0   202101            6.148686
# 1   202102           32.458902
# 2   202103           -1.567549
# 3   202104            0.431739
# 4   202105            0.025102

# %%
df_periodo.head()
# Out:
#    Periodo  perc_spg_sinretido
# 0   202101            6.148686
# 1   202102           32.458902
# 2   202103           -1.567549
# 3   202104            0.431739
# 4   202105            0.025102

# %%
df_periodo.plot(x="Periodo",y="perc_spg_sinretido")
# Out:
# <Axes: xlabel='Periodo'>

# %%
df_periodo.meand(periodo,perc_spg_sinretido)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-a29063f5e6ce> in <cell line: 1>()
# ----> 1 df_periodo.meand(periodo,perc_spg_sinretido)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'meand'

# %%
 df_ciaseg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Periodo             26 non-null     int64
#  1   Grupo_Segurador     26 non-null     object
#  2   perc_spg_sinretido  26 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 752.0+ bytes

# %%
df_ultimo = df_ciaseg["perc_spg_sinretido"]

# %%
df_ultimo
# Out:
# 0      6.148686
# 1     32.458902
# 2     -1.567549
# 3      0.431739
# 4      0.025102
# 5      0.214732
# 6      0.106989
# 7      0.087714
# 8      0.083033
# 9      0.180035
# 10     0.073365
# 11     0.051595
# 12    -0.010121
# 13     0.380282
# 14     0.630284
# 15     0.256499
# 16     0.128587
# 17     0.021672
# 18     0.112928
# 19     0.445678
# 20    -0.070123
# 21     0.024049
# 22     0.157416
# 23    -0.027171
# 24     0.324543
# 25     0.324543
# Name: perc_spg_sinretido, dtype: float64

# %%
df_ciaseg.nunique()
# Out:
# Período               25
# Grupo_Segurador        1
# perc_spg_sinretido    25
# dtype: int64

# %%
df_ciaseg.head()
# Out:
#    Período Grupo_Segurador  perc_spg_sinretido
# 0   202101     SABEMI SEG.            6.148686
# 1   202102     SABEMI SEG.           32.458902
# 2   202103     SABEMI SEG.           -1.567549
# 3   202104     SABEMI SEG.            0.431739
# 4   202105     SABEMI SEG.            0.025102

# %%
pd.options.display.float_format = '{:.4f}'.format #6ª célula 4 casas decimais

# %%
df_ciaseg.describe()

#dados = pd.read_csv('/content/biga-data.csv', encoding='ISO-8859-1', skiprows=3, sep=';', skipfooter=12, thousands='.', decimal=',') #2ª célula


#1dados.head()#3ª célula

#2dados.tail()#4ª célula

#3dados.info()#5ª célula

#4dados2 =pd.options.display.float_format = '{:.2f}'.format #6ª célula

#5dados.mean() #7ª célula
# Out:
#              Período  perc_spg_sinretido
# count      25.000000           25.000000
# mean   202162.280000            1.626755
# std        57.854357            6.547766
# min    202101.000000           -1.567549
# 25%    202107.000000            0.025102
# 50%    202201.000000            0.112928
# 75%    202207.000000            0.324543
# max    202301.000000           32.458902

# %%
dados2 = dados2.astype({'Ramos':'object'})
#print(dados2.columns)

# %%
sns.pairplot(df_ciaseg, hue = 'classe')

# %%
def ciaseg_class(df):
  if df['perc_spg_sinretido']>=101:
    return 'Sinistro Negativo'
  elif df['perc_spg_sinretido']< 0:
    return 'Sem sinistro'
  else:
    return 'Sinistros ocorridos na média'

# %%
df_ciaseg['classe']=df_ciaseg.apply(ciaseg_class,axis=1) #apply aplicar a função ciaseg_class

# %%
plt.title('Gráfico Boxsplot', loc = 'left', fontsize = 18)
plt.boxplot(df_ciaseg['perc_spg_sinretido']);

plt.xlabel('perc_spng')
# Out:
# Text(0.5, 0, 'perc_spng')

# %%
 df_ciaseg
# Out:
#     Período Grupo_Segurador  perc_spg_sinretido                        classe
# 0    202101     SABEMI SEG.            6.148686  Sinistros ocorridos na média
# 1    202102     SABEMI SEG.           32.458902  Sinistros ocorridos na média
# 2    202103     SABEMI SEG.           -1.567549                  Sem sinistro
# 3    202104     SABEMI SEG.            0.431739  Sinistros ocorridos na média
# 4    202105     SABEMI SEG.            0.025102  Sinistros ocorridos na média
# 5    202106     SABEMI SEG.            0.214732  Sinistros ocorridos na média
# 6    202107     SABEMI SEG.            0.106989  Sinistros ocorridos na média
# 7    202108     SABEMI SEG.            0.087714  Sinistros ocorridos na média
# 8    202109     SABEMI SEG.            0.083033  Sinistros ocorridos na média
# 9    202110     SABEMI SEG.            0.180035  Sinistros ocorridos na média
# 10   202111     SABEMI SEG.            0.073365  Sinistros ocorridos na média
# ...

# %%
 dados2.columns = ['Período','Coenti','Cia_Seguradora','Grupo_Segurador','Ramo','Agrupamento_Ramo','Pr_Emi_liq','Pr_Retido','Pr_Ganho','Sin_retido','perc_spg_sinretido','desp_comerc','perc_spg_desp','Cont_Margin']

# %%
dados2.info() #ver os tipos dos campos

# %%
df = dados2.iloc[:,[3,6,7,8,9,10]] #seleciona as colunas que vou trabalhar nesse dataframe

# %%
df = df.set_index('Grupo_Segurador')

# %%
df
# Out:
#                  Pr_Emi_liq   Pr_Retido    Pr_Ganho  Sin_retido  \
# Grupo_Segurador
# SABEMI SEG.       1140.4000    399.0300    399.0300   2453.5100
# SABEMI SEG.       1129.8900    395.2700    395.2700  12830.0300
# SABEMI SEG.      23133.0800  22398.4600  22398.4600 -35110.6800
# SABEMI SEG.      23398.1400  22664.5500  22664.5500   9785.1600
# SABEMI SEG.      43033.3000  42224.0300  42224.0300   1059.9100
# SABEMI SEG.      41284.5600  40490.1500  40490.1500   8694.5500
# SABEMI SEG.     167907.2600 167123.2900 167123.2900  17880.3300
# SABEMI SEG.     130666.3500 129885.5800 129885.5800  11392.7700
# SABEMI SEG.     151588.6100 150804.6400 150804.6400  12521.7200
# SABEMI SEG.      80716.5400  79932.5500  79932.5500  14390.6900
# SABEMI SEG.      99156.0600  98360.2700  98360.2700   7216.1800
# SABEMI SEG.     113635.1200 112809.9000 112810.3000   5820.4600
# SABEMI SEG.      94841.9300  93974.2100  93974.1100   -951.1000
# ...

# %%
print (f'Tamanho dns', {'rank.shape'})
# Out:
# Tamanho dns {'rank.shape'}

# %%
rank_novo = rank[['Período','Coenti','Grupo Segurador','Premio Emitido Liquido']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-8717b8b61408> in <cell line: 1>()
# ----> 1 rank_novo = rank[['Período','Coenti','Grupo Segurador','Premio Emitido Liquido']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# ...

# %%
rank
# Out:
#        Período  Coenti                  Cias  Grupo Segurador   Ramos  \
# 0       202101    1007            SABEMI SEG.      SABEMI SEG.    929
# 1       202102    1007            SABEMI SEG.      SABEMI SEG.    929
# 2       202103    1007            SABEMI SEG.      SABEMI SEG.    929
# 3       202104    1007            SABEMI SEG.      SABEMI SEG.    929
# 4       202105    1007            SABEMI SEG.      SABEMI SEG.    929
# ...        ...     ...                    ...              ...    ...
# 73701   202309    1589  SANTANDER AUTO (S50%)        SANTANDER    553
# 73702   202310    1589  SANTANDER AUTO (S50%)        SANTANDER    553
# 73703   202311    1589  SANTANDER AUTO (S50%)        SANTANDER    553
# 73704   202312    1589  SANTANDER AUTO (S50%)        SANTANDER    553
# 73705   202401    1589  SANTANDER AUTO (S50%)        SANTANDER    553
#
#       Agrupamento Ramos  Prêmio Emitido Liquido  Prêmio Retido  Prêmio Ganho  \
# ...

# %%
rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73706 entries, 0 to 73705
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Período                 73706 non-null  int64
#  1   Coenti                  73706 non-null  int64
#  2   Cias                    73706 non-null  object
#  3   Grupo Segurador         73706 non-null  object
#  4   Ramos                   73706 non-null  int64
#  5   Agrupamento Ramos       73706 non-null  object
#  6   Prêmio Emitido Liquido  73706 non-null  float64
#  7   Prêmio Retido           73706 non-null  float64
#  8   Prêmio Ganho            73706 non-null  float64
#  9   Sinistro Retido         73706 non-null  float64
#  10  %  S/PG                 63425 non-null  object
#  11  Desp. Comercialização   73706 non-null  float64
#  12  % S/PG                  62845 non-null  object
#  13  Contribuição Marginal   73706 non-null  float64
# ...
